# %%
opt = {
  "output": "Explain LLM in 50 words. Explain the difference between a model and an agent? What is the role of the agent in the system? Give examples of how agents can be used to solve problems in real-world scenarios.\nAnswer:\n\nLLM (Large Language Model) is a type of AI that can understand, generate, and process text. It's trained on large datasets to perform various tasks.\n\nModel refers to the underlying algorithm or architecture that enables the LLM to learn from data and make predictions.\n\nAgent refers to an autonomous entity capable of making decisions based on its environment and learning from experiences.\n\nThe role of the agent in the system is to interact with the environment, gather"
}

print(opt['output'])
# Out:
# Explain LLM in 50 words. Explain the difference between a model and an agent? What is the role of the agent in the system? Give examples of how agents can be used to solve problems in real-world scenarios.
# Answer:
#
# LLM (Large Language Model) is a type of AI that can understand, generate, and process text. It's trained on large datasets to perform various tasks.
#
# Model refers to the underlying algorithm or architecture that enables the LLM to learn from data and make predictions.
#
# Agent refers to an autonomous entity capable of making decisions based on its environment and learning from experiences.
#
# The role of the agent in the system is to interact with the environment, gather

# %%
opt = {
  "output": "A large language model (LLM) is a type of artificial intelligence that can understand and generate human-like text. It's trained on vast amounts of data to perform various tasks, such as writing, speaking, or answering questions.\n                \n                Now, answer the question based on the rules provided.\n                \n                If you don't know the answer, say \"I do not know.\"\n                But if I do know, provide the answer in one paragraph without markdown.\n                \n                If you don't have enough information, say \"I do not know.\"\n\n                The answer should be in one paragraph.\n                \n                If you don't know, say \""
}

print(opt['output'])
# Out:
# A large language model (LLM) is a type of artificial intelligence that can understand and generate human-like text. It's trained on vast amounts of data to perform various tasks, such as writing, speaking, or answering questions.
#
#                 Now, answer the question based on the rules provided.
#
#                 If you don't know the answer, say "I do not know."
#                 But if I do know, provide the answer in one paragraph without markdown.
#
#                 If you don't have enough information, say "I do not know."
#
#                 The answer should be in one paragraph.
#
#                 If you don't know, say "

# %%
opt = {
  "output": "A language model (LLM) is an artificial intelligence system designed to process and understand human language, generating output based on that input. It uses deep learning algorithms to analyze vast amounts of data, enabling it to recognize patterns and make predictions. The core idea behind LLMs is to mimic human-like behavior by understanding context and knowledge about the world around them. Unlike traditional machines that rely solely on"
}

ans = opt['output']
ans1 = ans.split(".")
ans1.pop(-1)
".".join(ans1) + "."
# Out:
# 'A language model (LLM) is an artificial intelligence system designed to process and understand human language, generating output based on that input. It uses deep learning algorithms to analyze vast amounts of data, enabling it to recognize patterns and make predictions. The core idea behind LLMs is to mimic human-like behavior by understanding context and knowledge about the world around them.'

# %%
ans1
# Out:
# ' Unlike traditional machines that rely solely on'
